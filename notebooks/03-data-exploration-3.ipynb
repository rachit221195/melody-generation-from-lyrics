# %%
import pandas as pd
import numpy as np

import os
from pathlib import Path

# %%
data_dir = "../data/raw/"

# %%
cwd = Path(os.curdir)

# %%
data_dir = cwd / 'data' / 'raw'

# %%
file_dir = Path().cwd()
# uncomment when using in a .py file
# file_dir = Path(__file__)
base_dir = file_dir.parents[0]
data_dir = base_dir / 'data'
raw_data_dir = data_dir / 'raw'

# %%
word_level_dir = raw_data_dir / 'word_level_29'

# %%
syllable_level = raw_data_dir / 'syllable_level_npy_39'

# %%
fnames_s = syllable_level.iterdir()

# %%
for i in fnames_s:
    print(i)
    data = np.load(i, allow_pickle=True)
    data = data[0][2]
    print(data)
#     print(data[0][0][0])
#     print(len(data[0]))
#     print(data[1][0][0])
#     print(len(data[0]))
#     print(data[2][0][0])
#     print(len(data[0]))
    break
# Out:
# /Users/rachitjain/Desktop/Projects/melody-generation-from-lyrics/data/raw/syllable_level_npy_39/b97dc283afc183df3589b0102b8bc572.npy
# ['RACEY', 'Ooh', 'ooh', 'yeah', 'yeah', 'yeah', 'Aa', 'aa', 'aa', 'aa', 'When', 'I', 'met', 'you', 'you', 'were', 'sev', 'teen', 'Not', 'just', 'an', 'oth', 'er', 'teen', 'age', 'queen', 'And', 'then', 'I', 'took', 'you', "ev'", 'ry', 'where', "you've", 'been', 'In', 'and', 'out', 'of', 'love', 'then', 'back', 'a', 'gain', 'When', 'I', 've', 'ry', 'first', 'saw', 'you', 'ba', 'by', 'I', 'knew', 'Ooh', 'dar', 'ling', 'it', 'had', 'to', 'be', 'you', "You're", 'the', 'one', 'who', 'takes', 'me', 'high', 'er', 'Ooh', 'ba', 'by', 'set', 'my', 'heart', 'on', 'fi', 're', 'aa', 'aa', 'Come', 'on', 'ba', 'by', 'lay', 'your', 'love', 'on', 'Ooh', 'ba', 'by', 'let', 'your', 'love', 'go', 'free', 'now', 'Come', 'on', 'ba', 'by', 'lay', 'your', 'love', 'on', 'me', 'Ba', 'by', 'ba', 'by', 'ba', 'by', 'got', 'the', 'love', 'I', 'need', 'Now', "I've", 'tast', 'ed', 'your', 'sweet', 'lips', 'Ooh', 'dar', 'ling', 'I', 'know', 'what', 'I', 'missed', 'You', 'gave', 'me', 'more', 'than', 'I', 'could', 'ev', 'er', 'take', 'With', "ev'", 'ry', 'word', 'and', "ev'", 'ry', 'move', 'you', 'make', 'now', 'I', "can't", 'be', 'lieve', 'that', 'af', 'ter', 'this', 'time', 'I', 'got', "ev'", 'ry', 'lit', 'tle', 'thing', 'I', 'ev', 'er', 'hoped', 'to', 'find', 'What', 'ev', 'er', 'you', 'got', 'I', "can't", 'let', 'up', "It's", 'you', 'ba', 'by', "it's", 'you', 'that', 'I', 'love', 'aa', 'aa', 'Come', 'on', 'ba', 'by', 'lay', 'your', 'love', 'on', 'me', 'Ooh', 'ba', 'by', 'let', 'your', 'love', 'go', 'free', 'now', 'Come', 'on', 'ba', 'by', 'lay', 'your', 'love', 'on', 'me', 'Ba', 'by', 'ba', 'by', 'ba', 'by', 'got', 'the', 'love', 'I', 'now', 'come', 'ba', 'lay', 'love', 'me', 'by', 'by', 'by', 'your', 'on', 'Ooh', 'on', 'by', 'your', 'on', 'Ba', 'ba', 'ba', 'lay', 'love', 'me', 'on', 'by', 'your', 'on', 'Ooh', 'by', 'your', 'go', 'now', 'Come', 'ba', 'by', 'lay', 'your', 'love', 'on', 'me', 'Ba', 'by', 'ba', 'by', 'ba', 'by', 'got', 'the', 'love', 'need', 'Come', 'on', 'ba', 'by', 'lay', 'your', 'love', 'me', 'Ooh', 'ba', 'by', 'let', 'your', 'love', 'go', 'free', 'now', 'Come', 'on', 'ba', 'by', 'lay', 'your', 'love', 'on', 'me', 'Ba', 'by', 'ba', 'by', 'ba', 'by', 'got', 'the', 'love', 'I', 'need', 'now', 'Come', 'on', 'ba', 'by', 'lay', 'your', 'love', 'on', 'me', 'Ooh', 'ba', 'by', 'let', 'your', 'love', 'go', 'free', 'now', 'Come', 'on', 'ba', 'by', 'lay', 'your', 'love', 'on', 'me', 'Ba', 'by', 'ba']

# %%
count
# Out:
# 1

# %%
type(data)
# Out:
# numpy.ndarray

# %%
data.shape
# Out:
# (3,)

# %%
data[0][0]
# Out:
# [0.0, 0.3314605250000042, 391.99543598174927, 127.0]

# %%
data[1][0]
# Out:
# [67.0, 1.0, 0.0]

# %%
data[2][0]
# Out:
# 'Remixed'

# %%
data[2]
# Out:
# ['Remixed',
#  'by',
#  'RicBNH',
#  'O',
#  'ceans',
#  'a',
#  'part',
#  'day',
#  'af',
#  'ter',
#  'And',
#  'I',
#  'slow',
#  'ly',
#  'go',
#  'in',
#  'sane',
#  'I',
#  'hear',
#  'your',
#  'voice',
#  'on',
#  'the',
#  'line',
#  'But',
#  'it',
#  'does',
#  "n't",
#  'stop',
#  'the',
#  'pain',
#  'If',
#  'I',
#  'see',
#  'you',
#  'next',
#  'to',
#  'ne',
#  'ver',
#  'How',
#  'can',
#  'we',
#  'say',
#  'for',
#  'e',
#  'ver',
#  'Where',
#  'ver',
#  'you',
#  'go',
#  'What',
#  'e',
#  'ver',
#  'you',
#  'do',
#  'I',
#  'will',
#  'be',
#  'right',
#  'here',
#  'wait',
#  'ing',
#  'for',
#  'you',
#  'What',
#  'e',
#  'ver',
#  'it',
#  'takes',
#  'Or',
#  'how',
#  'my',
#  'heart',
#  'breaks',
#  'I',
#  'will',
#  'be',
#  'right',
#  'here',
#  'wait',
#  'ing',
#  'for',
#  'you',
#  'I',
#  'took',
#  'for',
#  'grant',
#  'ed',
#  'the',
#  'times',
#  'That',
#  'I',
#  'thought',
#  'would',
#  'last',
#  'some',
#  'how',
#  'I',
#  'hear',
#  'the',
#  'laugh',
#  'ter',
#  'I',
#  'taste',
#  'the',
#  'tears',
#  'But',
#  'I',
#  "can't",
#  'get',
#  'near',
#  'you',
#  'now',
#  'Oh',
#  "can't",
#  'you',
#  'see',
#  'it',
#  'ba',
#  'by',
#  "You've",
#  'got',
#  'me',
#  'go',
#  "in'",
#  'cra',
#  'zy',
#  'Where',
#  'ver',
#  'you',
#  'go',
#  'What',
#  'e',
#  'ver',
#  'you',
#  'do',
#  'I',
#  'will',
#  'be',
#  'right',
#  'here',
#  'wait',
#  'ing',
#  'for',
#  'you',
#  'What',
#  'e',
#  'ver',
#  'it',
#  'takes',
#  'Or',
#  'how',
#  'my',
#  'heart',
#  'breaks',
#  'I',
#  'will',
#  'be',
#  'right',
#  'here',
#  'wait',
#  'ing',
#  'for',
#  'you',
#  'I',
#  'won',
#  'der',
#  'how',
#  'we',
#  'can',
#  'sur',
#  'vive',
#  'This',
#  'ro',
#  'mance',
#  'But',
#  'in',
#  'the',
#  'end',
#  'if',
#  "I'm",
#  'with',
#  'you',
#  "I'll",
#  'take',
#  'the',
#  'chance',
#  'Oh',
#  "can't",
#  'you',
#  'see',
#  'it',
#  'ba',
#  'by',
#  "You've",
#  'got',
#  'me',
#  'go',
#  "in'",
#  'cra',
#  'zy',
#  'Where',
#  'ver',
#  'you',
#  'go',
#  'What',
#  'e',
#  'ver',
#  'you',
#  'do',
#  'I',
#  'will',
#  'be',
#  'right',
#  'here',
#  'wait',
#  'ing',
#  'for',
#  'you',
#  'What',
#  'e',
#  'ver',
#  'it',
#  'takes',
#  'Or',
#  'how',
#  'my',
#  'heart',
#  'breaks',
#  'I',
#  'will',
#  'be',
#  'right',
#  'here',
#  'wait',
#  'ing',
#  'for',
#  'you',
#  'AND',
#  'RicBNH',
#  'world',
#  'on',
#  'and',
#  'one',
#  'save',
#  'but',
#  "It's",
#  'what',
#  'sire',
#  'make',
#  'peo',
#  'do',
#  'dreamed',
#  "I'd",
#  'some',
#  'like',
#  "I'd",
#  'er',
#  'that',
#  'love',
#  'bo',
#  'like',
#  'No',
#  "don't",
#  'fall',
#  'I',
#  'na',
#  'in',
#  'with',
#  'you!',
#  'game',
#  'make',
#  'this',
#  'what',
#  'wick',
#  'thing',
#  'do',
#  'let',
#  'dream',
#  'you',
#  'a',
#  'thing',
#  'say',
#  'never',
#  'this',
#  'a',
#  'ed',
#  'to',
#  'to',
#  'me',
#  'of',
#  'And',
#  "don't",
#  'na',
#  'in',
#  'No',
#  "don't",
#  'fall',
#  'you!',
#  'world',
#  'on',
#  'and',
#  'one',
#  'save',
#  'but',
#  "It's",
#  'what',
#  'sire',
#  'make',
#  'peo',
#  'do',
#  'nev',
#  'dreamed',
#  "I'd",
#  'some',
#  'like',
#  "I'd",
#  'er',
#  'that',
#  'love',
#  'bo',
#  'you',
#  'I',
#  'wanna',
#  'in',
#  'No',
#  "don't",
#  'fall',
#  'love',
#  'th',
#  'u!',
#  'th',
#  'Ho',
#  'on',
#  'the',
#  'Be',
#  'I',
#  'ev',
#  'want',
#  'mo',
#  'This',
#  'er',
#  'ing',
#  'ld',
#  'es',
#  'through',
#  'oth',
#  'do',
#  'r',
#  'you',
#  'and',
#  'mind',
#  'not',
#  'rase',
#  'beau',
#  'of',
#  'face',
#  'for',
#  'while',
#  'you',
#  'me',
#  'ter',
#  'u',
#  'on',
#  'the',
#  'hold',
#  'to',
#  'mem',
#  'ries',
#  'wish',
#  'I',
#  'give',
#  'some',
#  'more',
#  'I',
#  'be',
#  'How',
#  'we',
#  'some',
#  'that',
#  'us',
#  'sur',
#  'r',
#  's',
#  'Pro',
#  'es',
#  'vai',
#  'love',
#  'is',
#  'but',
#  'dis',
#  'is',
#  'What',
#  'pens',
#  'Do',
#  'break',
#  'oth',
#  'our',
#  'play',
#  'fool',
#  "don't",
#  'o',
#  'feel',
#  'a',
#  'Hold',
#  'to',
#  'nights',
#  'on',
#  'the',
#  'o',
#  'I',
#  'that',
#  'could',
#  'you',
#  'Well',
#  'think',
#  "I've",
#  'true',
#  'e',
#  'ery',
#  'dy',
#  'but',
#  'e',
#  'the',
#  'I',
#  'a',
#  'you',
#  'my',
#  'long',
#  'be',
#  'Ev',
#  'time',
#  'look',
#  'to',
#  'eyes',
#  'am',
#  'less',
#  'a',
#  'r',
#  'that',
#  'some',
#  "I've",
#  'search',
#  'for',
#  'right',
#  'r',
#  'Hold',
#  'to',
#  'nights',
#  'on',
#  'the',
#  'o',
#  'I',
#  'that',
#  'could',
#  'you',
#  'Oh',
#  'h',
#  'h',
#  'I',
#  'uld',
#  'e',
#  'ur',
#  'Hold',
#  'to',
#  'nights',
#  "I'm",
#  'tired',
#  'be',
#  'here',
#  'pressed',
#  'my',
#  'ish',
#  'and',
#  'you',
#  'to',
#  'I',
#  'that',
#  'would',
#  'leave',
#  'your',
#  'ence',
#  'lin',
#  'here',
#  'it',
#  'leave',
#  'a',
#  'These',
#  "won't",
#  'pain',
#  'just',
#  'real',
#  'just',
#  'much',
#  'time',
#  'not',
#  'rase',
#  'you',
#  "I'd",
#  'a',
#  'of',
#  'tears',
#  "you'd",
#  "I'd",
#  'a',
#  'of',
#  'fears',
#  'I',
#  'your',
#  'through',
#  'these',
#  'But',
#  'still',
#  'of',
#  'You',
#  'to',
#  'ti',
#  'me',
#  'your',
#  'o',
#  'ing',
#  'but',
#  'bound',
#  'the',
#  'you',
#  'be',
#  'Your',
#  'it',
#  'my',
#  'pleas',
#  'dreams',
#  'voice',
#  'a',
#  'san',
#  'in',
#  'These',
#  "won't",
#  'to',
#  'This',
#  'is',
#  'too',
#  'just',
#  'that',
#  'not',
#  'When',
#  'cried',
#  'wipe',
#  'way',
#  'your',
#  'When',
#  'scream',
#  'a',
#  'of',
#  'And',
#  'held',
#  'hand',
#  'of',
#  'years',
#  'you',
#  'have',
#  'me',
#  'tried',
#  'hard',
#  'tell',
#  'self',
#  "you're",
#  'But',
#  'still',
#  'me',
#  'been',
#  'lone',
#  'long',
#  "I'd",
#  'a',
#  'your',
#  'scream',
#  'fight',
#  'of',
#  'fears',
#  'I',
#  'your',
#  'through',
#  'years',
#  'have',
#  'me',
#  'Me',
#  'RicBNH',
#  'at',
#  'when',
#  'world',
#  'sleeping',
#  'up',
#  'think',
#  'you',
#  'I',
#  'on',
#  'star',
#  'some',
#  'you',
#  'ing',
#  'me',
#  'Cause',
#  'dream',
#  'of',
#  'Till',
#  'mor',
#  'be',
#  'tight',
#  "there's",
#  'in',
#  'world',
#  'rath',
#  'be',
#  'here',
#  'room',
#  'bout',
#  'and',
#  'Won',
#  'if',
#  'ev',
#  'see',
#  'and',
#  'Won',
#  'if',
#  'know',
#  'there',
#  'you',
#  'in',
#  'Would',
#  'see',
#  'in',
#  'Would',
#  'even',
#  'just',
#  'na',
#  'you',
#  'But',
#  'far',
#  'have',
#  'dreams',
#  'you',
#  'wait',
#  'the',
#  'and',
#  'courage',
#  'How',
#  'you',
#  'be',
#  'Of',
#  'Till',
#  'mor',
#  'be',
#  'ing',
#  'tight',
#  "there's",
#  'where',
#  'world',
#  'be',
#  'here',
#  'my',
#  'dream',
#  'a',
#  'you',
#  'me',
#  'at',
#  'when',
#  'world',
#  'sleeping',
#  'up',
#  'think']

# %%
fnames = word_level_dir.iterdir()

# %%
for i in fnames:
    data = np.load(i, allow_pickle=True)
    print(data[0][1])
    data = data[0][2]
    print(data)
    break
# Out:
# [[[67.0, 1.0, 0.0]], [[72.0, 1.0, 0.0]], [[74.0, 1.0, 0.0]], [[74.0, 2.0, 0.0], [76.0, 3.0, 0.0]], [[74.0, 1.0, 0.0], [72.0, 1.0, 0.0]], [[74.0, 0.5, 0.0]], [[72.0, 0.5, 0.0], [69.0, 8.0, 0.0]], [[69.0, 1.0, 0.0]], [[71.0, 1.0, 0.0]], [[72.0, 1.0, 0.0], [74.0, 2.0, 0.0]], [[71.0, 3.0, 0.0]], [[71.0, 1.0, 0.0], [67.0, 6.0, 0.0]], [[67.0, 1.0, 0.0]], [[72.0, 1.0, 0.0]], [[74.0, 1.0, 0.0]], [[74.0, 2.0, 0.0]], [[76.0, 4.0, 0.0]], [[72.0, 1.0, 0.0]], [[72.0, 0.5, 0.0]], [[74.0, 1.0, 0.0]], [[72.0, 0.25, 0.0]], [[71.0, 1.0, 0.0]], [[72.0, 1.0, 0.0]], [[72.0, 2.0, 0.0]], [[71.0, 3.0, 0.0]], [[72.0, 1.0, 0.0]], [[72.0, 4.0, 0.0]], [[72.0, 0.5, 0.0]], [[72.0, 1.0, 0.0]], [[74.0, 1.0, 0.0]], [[76.0, 1.0, 0.0], [77.0, 3.0, 0.0]], [[76.0, 1.0, 0.0]], [[72.0, 2.0, 0.0]], [[74.0, 0.25, 0.0]], [[72.0, 0.25, 0.0]], [[72.0, 1.0, 8.0], [74.0, 1.0, 0.0], [76.0, 1.0, 0.0]], [[76.0, 1.0, 4.0], [72.0, 2.0, 0.0]], [[72.0, 0.5, 0.0]], [[67.0, 4.0, 0.0]], [[79.0, 1.0, 1.0], [79.0, 1.0, 0.0], [77.0, 1.0, 0.0]], [[76.0, 1.0, 0.0]], [[74.0, 2.0, 0.0]], [[74.0, 1.0, 2.0]], [[74.0, 1.0, 0.0]], [[76.0, 1.0, 0.0]], [[77.0, 1.0, 0.0]], [[76.0, 3.0, 0.0]], [[72.0, 1.0, 0.0], [72.0, 2.0, 0.0]], [[74.0, 2.0, 0.0]], [[76.0, 2.0, 0.0]], [[74.0, 2.0, 0.0], [72.0, 2.0, 0.0], [71.0, 1.0, 0.0]], [[69.0, 1.0, 0.0]], [[67.0, 4.0, 0.0]], [[79.0, 1.0, 0.0]], [[79.0, 1.0, 0.0]], [[77.0, 1.0, 0.0]], [[76.0, 1.0, 0.0]], [[74.0, 4.0, 0.0]], [[74.0, 1.0, 0.0]], [[74.0, 1.0, 0.0]], [[76.0, 1.0, 0.0]], [[77.0, 1.0, 0.0]], [[76.0, 3.0, 0.0]], [[72.0, 1.0, 0.0], [74.0, 2.0, 0.0]], [[76.0, 2.0, 0.0]], [[77.0, 2.0, 0.0]], [[67.0, 1.0, 32.0]], [[72.0, 1.0, 0.0]], [[74.0, 1.0, 0.0]], [[74.0, 2.0, 0.0], [76.0, 1.0, 0.0]], [[76.0, 1.0, 4.0]], [[72.0, 1.5, 0.0]], [[69.0, 6.0, 0.0]], [[69.0, 1.0, 0.0]], [[71.0, 1.0, 0.0]], [[72.0, 1.0, 0.0]], [[74.0, 3.0, 0.0]], [[71.0, 0.5, 0.0], [69.0, 0.5, 0.0]], [[67.0, 1.0, 1.0]], [[67.0, 6.0, 0.0]], [[72.0, 1.0, 0.0]], [[74.0, 1.0, 0.0], [74.0, 2.0, 0.0]], [[76.0, 3.0, 0.0]], [[77.0, 1.0, 0.0]], [[76.0, 1.0, 0.0]], [[72.0, 1.0, 0.0]], [[74.0, 0.25, 0.0]], [[69.0, 1.0, 8.0]], [[72.0, 1.0, 0.0]], [[74.0, 2.0, 0.0]], [[71.0, 3.0, 0.0]], [[72.0, 1.0, 0.0]], [[72.0, 6.0, 0.0]], [[74.0, 1.0, 0.0]], [[76.0, 1.0, 0.0]], [[77.0, 3.0, 0.0]], [[76.0, 1.0, 0.0], [72.0, 2.0, 0.0]], [[72.0, 0.5, 0.0]], [[72.0, 1.0, 8.0]], [[69.0, 0.5, 0.0]], [[74.0, 1.0, 0.0]], [[76.0, 1.0, 0.0]], [[77.0, 1.0, 0.0]], [[76.0, 3.0, 0.0]], [[72.0, 1.0, 0.0]], [[72.0, 2.0, 0.0], [74.0, 2.0, 0.0]], [[76.0, 2.0, 0.0]], [[74.0, 2.0, 0.0]], [[72.0, 2.0, 0.0], [71.0, 1.0, 0.0], [69.0, 1.0, 0.0]], [[67.0, 4.0, 0.0]], [[79.0, 1.0, 0.0]], [[79.0, 1.0, 0.0]], [[77.0, 1.0, 0.0]], [[76.0, 1.0, 0.0]], [[74.0, 4.0, 0.0]], [[74.0, 1.0, 0.0]], [[74.0, 1.0, 0.0]], [[76.0, 1.0, 0.0]], [[77.0, 1.0, 0.0]], [[76.0, 3.0, 0.0]], [[72.0, 1.0, 0.0]], [[74.0, 2.0, 0.0], [76.0, 2.0, 0.0]], [[77.0, 2.0, 0.0]], [[76.0, 2.0, 0.0]], [[76.0, 1.0, 2.0]], [[72.0, 1.0, 0.0], [72.0, 6.0, 0.0]], [[67.0, 1.0, 1.0]], [[72.0, 1.0, 0.0]], [[74.0, 1.0, 0.0]], [[76.0, 2.0, 0.0], [77.0, 1.0, 0.0]], [[67.0, 1.0, 4.0]], [[69.0, 6.0, 0.0], [72.0, 1.0, 1.0]], [[67.0, 1.0, 16.0]], [[72.0, 1.0, 0.0]], [[74.0, 1.0, 0.0]], [[76.0, 2.0, 0.0]], [[77.0, 1.0, 0.0]], [[67.0, 1.0, 0.0]], [[69.0, 4.0, 0.0]], [[72.0, 3.0, 0.0]], [[79.0, 1.0, 0.0]], [[79.0, 8.0, 0.0]], [[72.0, 1.0, 32.0]], [[76.0, 1.0, 0.0]], [[77.0, 3.0, 0.0]], [[76.0, 2.0, 0.0]], [[72.0, 1.0, 0.0], [74.0, 0.25, 0.0]], [[69.0, 0.25, 0.0]], [[69.0, 6.0, 0.0]], [[72.0, 1.0, 0.0]], [[74.0, 4.0, 0.0]], [[74.0, 1.0, 0.0]], [[74.0, 1.0, 0.0]], [[76.0, 1.0, 0.0]], [[77.0, 1.0, 0.0]], [[76.0, 3.0, 0.0], [72.0, 1.0, 0.0]], [[72.0, 2.0, 0.0]], [[74.0, 2.0, 0.0]], [[76.0, 2.0, 0.0], [74.0, 2.0, 0.0], [72.0, 2.0, 0.0]], [[71.0, 1.0, 0.0]], [[69.0, 1.0, 0.0]], [[67.0, 4.0, 0.0]], [[79.0, 1.0, 0.0]], [[79.0, 1.0, 0.0]], [[77.0, 1.0, 0.0]], [[76.0, 1.0, 0.0]], [[74.0, 4.0, 0.0]], [[74.0, 1.0, 0.0]], [[74.0, 1.0, 0.0]], [[76.0, 1.0, 0.0]], [[77.0, 1.0, 0.0]], [[76.0, 3.0, 0.0], [72.0, 1.0, ...
# [['Remixed'], ['by'], ['RicBNH'], ['Oceans', 'Oceans'], ['apart', 'apart'], ['day'], ['after', 'after'], ['And'], ['I'], ['slowly', 'slowly'], ['go'], ['insane', 'insane'], ['I'], ['hear'], ['your'], ['voice'], ['on'], ['the'], ['line'], ['But'], ['it'], ['stop'], ['the'], ['pain'], ['If'], ['I'], ['see'], ['you'], ['next'], ['to'], ['never', 'never'], ['How'], ['can'], ['we'], ['say'], ['forever', 'forever', 'forever'], ['Wherever', 'Wherever'], ['you'], ['go'], ['Whatever', 'Whatever', 'Whatever'], ['you'], ['do'], ['I'], ['will'], ['be'], ['right'], ['here'], ['waiting', 'waiting'], ['for'], ['you'], ['Whatever', 'Whatever', 'Whatever'], ['it'], ['takes'], ['Or'], ['how'], ['my'], ['heart'], ['breaks'], ['I'], ['will'], ['be'], ['right'], ['here'], ['waiting', 'waiting'], ['for'], ['you'], ['I'], ['took'], ['for'], ['granted', 'granted'], ['the'], ['times'], ['That'], ['I'], ['thought'], ['would'], ['last'], ['somehow', 'somehow'], ['I'], ['hear'], ['the'], ['laughter', 'laughter'], ['I'], ['taste'], ['the'], ['tears'], ['But'], ['I'], ['get'], ['near'], ['you'], ['now'], ['Oh'], ['you'], ['see'], ['it'], ['baby', 'baby'], ['got'], ['me'], ['you'], ['I'], ['will'], ['be'], ['right'], ['here'], ['waiting', 'waiting'], ['for'], ['you'], ['Whatever', 'Whatever', 'Whatever'], ['it'], ['takes'], ['Or'], ['how'], ['my'], ['heart'], ['breaks'], ['I'], ['will'], ['be'], ['right'], ['here'], ['waiting', 'waiting'], ['for'], ['you'], ['I'], ['wonder', 'wonder'], ['how'], ['we'], ['can'], ['survive', 'survive'], ['This'], ['romance', 'romance'], ['But'], ['in'], ['the'], ['end'], ['if'], ['with'], ['you'], ['take'], ['the'], ['chance'], ['Oh'], ['you'], ['see'], ['it'], ['baby', 'baby'], ['got'], ['me'], ['you'], ['I'], ['will'], ['be'], ['right'], ['here'], ['waiting', 'waiting'], ['for'], ['you'], ['Whatever', 'Whatever', 'Whatever'], ['it'], ['takes'], ['Or'], ['how'], ['my'], ['heart'], ['breaks'], ['I'], ['will'], ['be'], ['right'], ['here'], ['waiting', 'waiting'], ['for'], ['you'], ['AND']]

# %%
[i[0] for i in data]
# Out:
# ['Remixed',
#  'by',
#  'RicBNH',
#  'Oceans',
#  'apart',
#  'day',
#  'after',
#  'And',
#  'I',
#  'slowly',
#  'go',
#  'insane',
#  'I',
#  'hear',
#  'your',
#  'voice',
#  'on',
#  'the',
#  'line',
#  'But',
#  'it',
#  'stop',
#  'the',
#  'pain',
#  'If',
#  'I',
#  'see',
#  'you',
#  'next',
#  'to',
#  'never',
#  'How',
#  'can',
#  'we',
#  'say',
#  'forever',
#  'Wherever',
#  'you',
#  'go',
#  'Whatever',
#  'you',
#  'do',
#  'I',
#  'will',
#  'be',
#  'right',
#  'here',
#  'waiting',
#  'for',
#  'you',
#  'Whatever',
#  'it',
#  'takes',
#  'Or',
#  'how',
#  'my',
#  'heart',
#  'breaks',
#  'I',
#  'will',
#  'be',
#  'right',
#  'here',
#  'waiting',
#  'for',
#  'you',
#  'I',
#  'took',
#  'for',
#  'granted',
#  'the',
#  'times',
#  'That',
#  'I',
#  'thought',
#  'would',
#  'last',
#  'somehow',
#  'I',
#  'hear',
#  'the',
#  'laughter',
#  'I',
#  'taste',
#  'the',
#  'tears',
#  'But',
#  'I',
#  'get',
#  'near',
#  'you',
#  'now',
#  'Oh',
#  'you',
#  'see',
#  'it',
#  'baby',
#  'got',
#  'me',
#  'you',
#  'I',
#  'will',
#  'be',
#  'right',
#  'here',
#  'waiting',
#  'for',
#  'you',
#  'Whatever',
#  'it',
#  'takes',
#  'Or',
#  'how',
#  'my',
#  'heart',
#  'breaks',
#  'I',
#  'will',
#  'be',
#  'right',
#  'here',
#  'waiting',
#  'for',
#  'you',
#  'I',
#  'wonder',
#  'how',
#  'we',
#  'can',
#  'survive',
#  'This',
#  'romance',
#  'But',
#  'in',
#  'the',
#  'end',
#  'if',
#  'with',
#  'you',
#  'take',
#  'the',
#  'chance',
#  'Oh',
#  'you',
#  'see',
#  'it',
#  'baby',
#  'got',
#  'me',
#  'you',
#  'I',
#  'will',
#  'be',
#  'right',
#  'here',
#  'waiting',
#  'for',
#  'you',
#  'Whatever',
#  'it',
#  'takes',
#  'Or',
#  'how',
#  'my',
#  'heart',
#  'breaks',
#  'I',
#  'will',
#  'be',
#  'right',
#  'here',
#  'waiting',
#  'for',
#  'you',
#  'AND']
